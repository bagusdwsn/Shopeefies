# %%
import string
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("data/raw_scraped.csv", sep=',', encoding='latin1')
data['review'] = data['review'].astype(str)
data.head(10)
# Out:
#                                               review  rating
# 0  makasih sudah sampai paketan nya ...mas kurir ...     5.0
# 1        Barang nya cpt nympe nya,bgs.\nmksh lazada.     5.0
# 2         bahannya bagus. baju nya pas di pakai ð     5.0
# 3  alhmdllh brng udh nympe...alhmdllh jg bju ssua...     5.0
# 4  bajunya cantik walaupun warnanya aga' beda den...     5.0
# 5  dh nyampe Alhamduliah Semoga pelanggan ku suka...     5.0
# 6  barang udah nyampa kak . realpict banget kurir...     4.0
# 7  alhamdulillah sesuai harapan ðð muat bb ...     5.0
# 8  makasih..pesanan nya dah sampai dan sesuai apa...     5.0
# 9                               Good sesuai pesanan      5.0

# %%
# Create a new column for sentiment labels
data['sentimen'] = ''
# Iterate through the dataset and assign sentiment labels
for index, row in data.iterrows():
    rating = row['rating']
    
    if rating >3:
        data.at[index, 'sentimen'] = 'positif'
    else:
        data.at[index, 'sentimen'] = 'negatif'
data.head()
# Out:
#                                               review  rating sentimen
# 0  makasih sudah sampai paketan nya ...mas kurir ...     5.0  positif
# 1        Barang nya cpt nympe nya,bgs.\nmksh lazada.     5.0  positif
# 2         bahannya bagus. baju nya pas di pakai ð     5.0  positif
# 3  alhmdllh brng udh nympe...alhmdllh jg bju ssua...     5.0  positif
# 4  bajunya cantik walaupun warnanya aga' beda den...     5.0  positif

# %%
# proses case folding 
def casefolding(review):
    if isinstance(review, str):
        review = review.lower()
    return review

data['review'] = data['review'].apply(casefolding)
data.head(10)
# Out:
#                                               review  rating sentimen
# 0  makasih sudah sampai paketan nya ...mas kurir ...     5.0  positif
# 1        barang nya cpt nympe nya,bgs.\nmksh lazada.     5.0  positif
# 2         bahannya bagus. baju nya pas di pakai ð     5.0  positif
# 3  alhmdllh brng udh nympe...alhmdllh jg bju ssua...     5.0  positif
# 4  bajunya cantik walaupun warnanya aga' beda den...     5.0  positif
# 5  dh nyampe alhamduliah semoga pelanggan ku suka...     5.0  positif
# 6  barang udah nyampa kak . realpict banget kurir...     4.0  positif
# 7  alhamdulillah sesuai harapan ðð muat bb ...     5.0  positif
# 8  makasih..pesanan nya dah sampai dan sesuai apa...     5.0  positif
# 9                               good sesuai pesanan      5.0  positif

# %%
data.to_csv("labeled_ds.csv")

# %%
import re
import string
import emoji

def cleansing(review):
    if isinstance(review, str):
        review = review.strip(" ")
        review = re.sub('[^a-zA-Z]', ' ', review)
        review = re.sub(r'[?|$|.|!_:")(-+,]', '', review)
        review = re.sub(r'\d+', '', review)
        review = re.sub(r"\b[a-zA-Z]\b", "", review)
        review = re.sub('\s+', ' ', review)
        review = emoji.demojize(review)  # Convert emojis to text representation
    return review

data['review'] = data['review'].apply(cleansing)
data.head(10)
# Out:
#                                               review  rating sentimen
# 0  makasih sudah sampai paketan nya mas kurir nya...     5.0  positif
# 1          barang nya cpt nympe nya bgs mksh lazada      5.0  positif
# 2              bahannya bagus baju nya pas di pakai      5.0  positif
# 3  alhmdllh brng udh nympe alhmdllh jg bju ssuai ...     5.0  positif
# 4  bajunya cantik walaupun warnanya aga beda deng...     5.0  positif
# 5  dh nyampe alhamduliah semoga pelanggan ku suka...     5.0  positif
# 6  barang udah nyampa kak realpict banget kurirny...     4.0  positif
# 7           alhamdulillah sesuai harapan muat bb kg      5.0  positif
# 8  makasih pesanan nya dah sampai dan sesuai apa ...     5.0  positif
# 9                                good sesuai pesanan     5.0  positif

# %%
from nltk.tokenize import word_tokenize
#NLTK word tokenize
def word_tokenize_wrapper(text):
    if isinstance(text, str):
        return word_tokenize(text)
    else:
        return text
data['review'] = data['review'].apply(word_tokenize_wrapper)
data.head()
# Out:
#                                               review  rating sentimen
# 0  [makasih, sudah, sampai, paketan, nya, mas, ku...     5.0  positif
# 1  [barang, nya, cpt, nympe, nya, bgs, mksh, lazada]     5.0  positif
# 2       [bahannya, bagus, baju, nya, pas, di, pakai]     5.0  positif
# 3  [alhmdllh, brng, udh, nympe, alhmdllh, jg, bju...     5.0  positif
# 4  [bajunya, cantik, walaupun, warnanya, aga, bed...     5.0  positif

# %%
normalizad_word = pd.read_csv("normalisasi.csv")

normalizad_word_dict = {}

for index, row in normalizad_word.iterrows():
    if row[0] not in normalizad_word_dict:
        normalizad_word_dict[row[0]] = row[1] 

def normalized_term(document):
    if isinstance(document, str):
        return [normalizad_word_dict[term] if term in normalizad_word_dict else term for term in document]
    else:
        return document

data['review'] = data['review'].apply(normalized_term)

data['review'].head(20)
# Out:
# 0     [makasih, sudah, sampai, paketan, nya, mas, ku...
# 1     [barang, nya, cpt, nympe, nya, bgs, mksh, lazada]
# 2          [bahannya, bagus, baju, nya, pas, di, pakai]
# 3     [alhmdllh, brng, udh, nympe, alhmdllh, jg, bju...
# 4     [bajunya, cantik, walaupun, warnanya, aga, bed...
# 5     [dh, nyampe, alhamduliah, semoga, pelanggan, k...
# 6     [barang, udah, nyampa, kak, realpict, banget, ...
# 7        [alhamdulillah, sesuai, harapan, muat, bb, kg]
# 8     [makasih, pesanan, nya, dah, sampai, dan, sesu...
# 9                               [good, sesuai, pesanan]
# 10                [terbaik, mmng, pokoknya, gk, nyesel]
# 11    [barangx, udh, sampai, makasih, lazada, kurirx...
# 12    [lumayan, bagus, tapi, celananya, kecil, ngatung]
# 13                               [bagus, sesuai, harga]
# 14    [kecewa, lah, bajunya, besar, bnget, mcem, uku...
# 15                 [bajunya, bagus, real, pict, banget]
# 16    [sesuai, pesanan, suka, insyah, allah, next, o...
# 17    [bajunya, bagus, bangetttt, cuma, kepanjangan,...
# 18    [paket, nya, udah, mendarat, bajunya, sih, sam...
# 19    [bgs, bju, nya, tp, gde, bgt, tp, mau, jht, lg...
# Name: review, dtype: object

# %%
# proses stemming
! pip install Sastrawi
from sklearn.pipeline import Pipeline
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

def stemming(review):
    factory = StemmerFactory()
    stemmer = factory.create_stemmer()
    do = []
    for w in review:
        dt = stemmer.stem(w)
        do.append(dt)
    d_clean=[]
    d_clean=" ".join(do)
    #print(d_clean)
    return d_clean
data['review'] = data['review'].apply(stemming)

data.to_csv('shopeebersih.csv', index=False)
data_clean = pd.read_csv('shopeebersih.csv', encoding='latin1')
data_clean.head()
# Out:
# Requirement already satisfied: Sastrawi in c:\users\lenovo\anaconda3\lib\site-packages (1.0.1)
#                                               review  rating sentimen
# 0  makasih sudah sampai paket nya mas kurir nya d...     5.0  positif
# 1           barang nya cpt nympe nya bgs mksh lazada     5.0  positif
# 2                  bahan bagus baju nya pas di pakai     5.0  positif
# 3  alhmdllh brng udh nympe alhmdllh jg bju ssuai ...     5.0  positif
# 4  baju cantik walaupun warna aga beda dengan rea...     5.0  positif

# %%
import string
from sklearn.pipeline import Pipeline
import pandas as pd
import numpy as np
import re

# %%
data_clean = pd.read_csv('shopeebersih.csv', encoding='latin1')
data_clean.head()
# Out:
#                                               review  rating sentimen
# 0  makasih sudah sampai paket nya mas kurir nya d...     5.0  positif
# 1           barang nya cpt nympe nya bgs mksh lazada     5.0  positif
# 2                  bahan bagus baju nya pas di pakai     5.0  positif
# 3  alhmdllh brng udh nympe alhmdllh jg bju ssuai ...     5.0  positif
# 4  baju cantik walaupun warna aga beda dengan rea...     5.0  positif

# %%
# Example dataset of text and sentiment labels
data_clean.dropna(inplace=True)
texts = data_clean['review']
labels = data_clean['sentimen']
data_clean
# Out:
#                                                 review  rating sentimen
# 0    makasih sudah sampai paket nya mas kurir nya d...     5.0  positif
# 1             barang nya cpt nympe nya bgs mksh lazada     5.0  positif
# 2                    bahan bagus baju nya pas di pakai     5.0  positif
# 3    alhmdllh brng udh nympe alhmdllh jg bju ssuai ...     5.0  positif
# 4    baju cantik walaupun warna aga beda dengan rea...     5.0  positif
# ..                                                 ...     ...      ...
# 404  senang sesuai pesan rapi cmn jelbab nya sdikit...     5.0  positif
# 405  kirim cepat bngt barang sama persis kaya yang ...     5.0  positif
# 406             mantap baju istri saya sgt suka sekali     4.0  positif
# 407  sangat kecewa karna lain yang pes lain yang ki...     1.0  negatif
# 408                          bagus bgt bajuny aku suka     5.0  positif
#
# [406 rows x 3 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# Example dataset of text and sentiment labels
texts = data_clean['review']
labels = data_clean['sentimen']

# Preprocess and tokenize the text data
# Apply any necessary text cleaning or normalization techniques

# Vectorize the text data
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(texts)

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, labels, test_size=0.2, random_state=42)

# Initialize KNN classifier
knn = KNeighborsClassifier(n_neighbors=2)

# Train the KNN model
knn.fit(X_train, y_train)

# Make predictions on the testing set
y_pred = knn.predict(X_test)

# Evaluate the performance
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9024390243902439

# %%
import pickle

# Save the trained model to a file
filename = 'knn_model.pkl'
with open(filename, 'wb') as file:
    pickle.dump(knn, vectorizer, file)

# %%
new_texts=[]

# %%
import re
import json
import requests

url = 'https://shopee.co.id/Promo-9.9-Sepatu-Sneakers-Pria-Sepatu-Olahraga-Sporty-Running-Jogging-ALB-i.196776862.5446751258?sp_atk=debb4e81-bd50-4836-abe6-e75fe9495044&xptdk=debb4e81-bd50-4836-abe6-e75fe9495044'

r = re.search(r'i\.(\d+)\.(\d+)', url)
shop_id, item_id = r[1], r[2]
ratings_url = 'https://shopee.co.id/api/v2/item/get_ratings?filter=0&flag=1&itemid={item_id}&limit=20&offset={offset}&shopid={shop_id}&type=0'

offset = 0
max_revs = 10
new_texts = []

while True:
    data = requests.get(ratings_url.format(shop_id=shop_id, item_id=item_id, offset=offset)).json()

    if 'ratings' in data['data']:
        for rating in data['data']['ratings']:
            comment = rating['comment']

            # Skip empty strings and None values
            if comment is not None and comment != '' and comment.lower() != 'nan':
                new_texts.append(comment)

    if len(data['data']['ratings']) < 20 or 'ratings' not in data['data']:
        break

    offset += 20

# Print the scraped comments
for text in new_texts:
    print(text)
    print('-' * 80)
# Out:
# Paket nya sudah sampai dan barang nya sudah di terima oleh saya sendiri untuk bahan nya bagus sesuai dengan pesanan saya terimakasih
# --------------------------------------------------------------------------------
# Terimakasih . Barang bagus . Jahitannya rapi Dengan harga segitu sangat worth to buy
# Seller fast respon. Baik dan sopan
# Pengiriman oke
# Semoga makin lancar usahanya 😇
# --------------------------------------------------------------------------------
# Tampilan:Keren
# Warna:Grey
#
# Pas pisan euy saat di pakai, tidak kekecilan, pengiriman cepat, respon reseller baik, menjanjikan dan tidak kapok belanja disini. Amat sangat baik belanja disini. Hatur nuhuunnn dan sukses selaluu
# --------------------------------------------------------------------------------
# Warna:sesuai dengan pesanan
#
# Paket nya sudah sampai dan barang nya sudah di terima oleh saya sendiri untuk bahan nya bagus lah untuk harga segitu terimakasi nanti akan belanja lagi di sini
# --------------------------------------------------------------------------------
# Yeayy, akhirnya barang dah datang. Pengemasan &pengiriman nya super duffer ceffattt😚😗 seller nya juga ramah sekali❤❤. Baju nya juga bagus,suka sekali, sesuai dgn keinginan juga,baju nya juga lumayan tebel.
# --------------------------------------------------------------------------------
# Baru pertama kali order disini. Super duper cepet pengemasannya. Pesen siang dikirim saat itu juga. Bahan bagus harga murah meriah. Next bakal order disini lagi.
# --------------------------------------------------------------------------------
# Tampilan:Baru
# Warna:Biru Dongker
#
# Barang sampai dengan selamat dan sesuai pesanan,untuk respon toko bagus banget dan pengirimannya pun cepet Alhamdulillah saya suka gaes wkwkwkwk
# --------------------------------------------------------------------------------
# Bagusss.. Kainnya tebal.. Jahitannya rapi.. Cuma aku gk coccok sama warnanya.. Kukira coksu nya lebih terang.  Ini malah kayak seragam pramuka ...
# --------------------------------------------------------------------------------
# Pengiriman cepat kualitas produk bagus harga murah, respon penjual bagus
# --------------------------------------------------------------------------------
# Tampilan:lumayan
# Warna:hitam
#
# Bahannya lumayan. Pas dibadan 👍
# --------------------------------------------------------------------------------
# Baguss kok
# Hargaa juga murah
# Pengiriman cepet
# Seller ramahh
# Mantap
# --------------------------------------------------------------------------------
# barang oke lumayan tebal harga segitu dapat barang bagus oke banget lah
# --------------------------------------------------------------------------------
# Alhmdulilah brang sdh sampek cocok cuma kurang besar salah pilih ukuran tp barang bagus mksih kk
# --------------------------------------------------------------------------------
# Sesuai dengan harga, kainnya lumayan bagus jahitan rapi.
# --------------------------------------------------------------------------------
# Barang sesuai pesanan. Kondisi bagus.
# Pas dipakai suami saya. Terimakasih kak ☺️
# --------------------------------------------------------------------------------
# Ukuran sesuai tetapi bahan biasa aja kyk seragam anak sekolahan panas
# --------------------------------------------------------------------------------
# Pengiriman cepat kualitas produk bagus harga terbaik Terimakasih 🙏👍💯
# --------------------------------------------------------------------------------
# Bahannya lumayan tebel adem banget ga kaku gitu, recomended bnget nih...
# --------------------------------------------------------------------------------
# Kecewa aq tuu,, ukurannya XL kecil kayak ukuran M,, d suami aq ga muat.. Percuma beli mahal,, g sesuai expektasi 😢😢..
# --------------------------------------------------------------------------------
# Terimakasih ka,barangnya bagus, realpict
# besok² order lagi.
# --------------------------------------------------------------------------------
# Kecewa si dengan bahannya biasa saja dan masi banyak sisa benang bekas jahit
# Terima kasih 🙏
# --------------------------------------------------------------------------------
# Tampilan:kain lembut,warna sesuai harapan ,toskanya cakep
# --------------------------------------------------------------------------------
# ok lah untuk harga segitu jaitan rapi. pi bahanya agak tipis ya.. hehe
# --------------------------------------------------------------------------------
# Alhamdulillah barangnya sudah sampai, bagus, pengemasan rapih, harga terjangkau.
# Terimakasih
# --------------------------------------------------------------------------------
# Awal nya agak kecewa pesan 2 dtng nya cuma 1.. tapi setelah chat penjual nya dan Alhamdulillah respon nya baik dan langsung di kirim yg satunya..
# Buat kalian jgn langsung nilai jelek dulu karena namanya manusia pasti pernah hilaf.. harap di maklumi
# Tapi oke mantap tetep harus ramah yaa
# --------------------------------------------------------------------------------
# Tampilan:bagus
# Warna:item
#
# Bahanya bagus bgt, ga nyesel pokok ny udh duakali check out disini
# --------------------------------------------------------------------------------
# bahan bangus pengemasan cepat pengiriman sangat express jos tenan
# --------------------------------------------------------------------------------
# Tampilan:ok
# Warna:ok
#
# Terimakasih barangnya sudah sampai . Semoga awet
# --------------------------------------------------------------------------------
# Alhamdulillah pesanan Uda sampai baju nya bagus sesuai ama dipoto kualitasnya lumayan dengan harga segitu Abang kurir nya langganan .trimah kasih toko nya amanah trima kasih shopee.
# --------------------------------------------------------------------------------
# Alhamdulillah paketnya udh datang packingnya bagus,bajunya cantik,bgs makasih ya;)
# --------------------------------------------------------------------------------
# Menurutku sih tipis bahanya, harganya juga lumayan mahal, malah kaya baju pramuka jatuhnyaa
# --------------------------------------------------------------------------------
# Tampilan:baik
# Warna:baik
#
# Terima kasih banyak ya ka, barangnya sudah sampai dengan selamat. Sangat memuaskan sukses dan berkah selalu untuk tokonya Aamiin ......
# --------------------------------------------------------------------------------
# Real pict, pengiriman cepat, barang oke.. Pokoknya mah nice pisan lah untuk harga nya juga oke murah banget
# --------------------------------------------------------------------------------
# Kualitas sesuai harga kaya nya panas bahan nya tapi is ok lah
# --------------------------------------------------------------------------------
# Tampilan:lumayan untuk harga segini, mskipun agak tipis
# Warna:cream
# --------------------------------------------------------------------------------
# MaasyaaAllah bahan nya bagus,adem
# Packingnya jg bgss bgtt🥰
# --------------------------------------------------------------------------------
# Tampilan:Kemeja
# Warna:Coksu
#
# Bagus banget
# bahanya bagus
# jahitannya rapi
# packingannya rapi
# makasih seller
# --------------------------------------------------------------------------------
# Wrna baju pramuka,size XL nya kecil,jd terlalu ngepas kaya seragam tentara ngepres dibadan
# --------------------------------------------------------------------------------
# Barangnya bagus pas untuk saya,nyaman dipakai dan kainya halus dan juga murah meriah lagi masok pokoke
# --------------------------------------------------------------------------------
# Pengirimannya cepat, pengemasan rapi.kualitas barang sesuai dengan harga, bahannya lumayan panas
# --------------------------------------------------------------------------------
# Warna coksunya ga sesuai ekspektasi aku😄 ini sih mirip bgt kaya seragam pramuka sekolah,, cuma bedanya kancingnya item aja...
# Tpi yaudah deh gapapa kok😊
# --------------------------------------------------------------------------------
# Bajunya sangat bagussss sesuai pesanan
# Pengiriman sangat cepat nex order lagi thnks seller
# Barang murah tapi tk murahan ok
# --------------------------------------------------------------------------------
# Bahan bagus bgt,halus,sesuai gambar...tp uk XL nya kurang besar...respon penjual cepat.pengirimab jg cepat👍👍
# --------------------------------------------------------------------------------
# Terimakaaih mbak, barangnya dah sampai dan sesuai pesanan 🙏😊
# --------------------------------------------------------------------------------
# Klo dlu bli prtama wrna biru itu bagus bahannya agak licin2 gmana gtu, skrg bli yg k2 bahannya sprti.
# --------------------------------------------------------------------------------
# Ukuranx dilebihin lagi,,yg biasa L harusnya XL
# Bahanx lumayan
# --------------------------------------------------------------------------------
# Tampilan:bagus
# Warna:creme
#
# Bagus bahannya adem , thanks seller ❤️🥰semoga nanti jd langganan 🤭
# --------------------------------------------------------------------------------
# Tampilan:biasa aja
# Warna:navy
#
# biasa aja . untk harga sgitu sya kira mahal. bahannya jga biasa aja tuh. entahlahhh..
# --------------------------------------------------------------------------------
# Bagus, ukurannya juga pas, tapi agak lucu, kaya anak pramuka pas doi pke. Pengirimannya nuga cepat banget
# --------------------------------------------------------------------------------
# Alhamdulillah pesanan Ku Dateng lagi cepet banget sampeknya respon penjualnya juga ramah aaaa suka 😘 mau order lagi
# --------------------------------------------------------------------------------
# Barang nya sdh sampai, bagus bahannya,puas dah pokoknya
# --------------------------------------------------------------------------------
# Alhamdulillah paketnya udah nympai brnya bagus banget besok beli lagi iyak
# --------------------------------------------------------------------------------
# Bahan Bagus.  Pengiriman cepat kwalitas mantab.  Harga oke..  Makasihhh konsumen ku suka
# --------------------------------------------------------------------------------
# Kaget banget masi ada label harganya segitu mahalnya.  Tapi padahal bayarnya cuma 70 ribuan sama ongkri cod bahanya juga bagussss😍😍😍😍😍
# --------------------------------------------------------------------------------
# Bagus keren dengan harga segitu mah cuma warnanya gelap bgt yah jadi kaya keliatan item gitu pdhal abu tua yudh deh gpp ttp bagus ko lain kali kalo butuh baju kokoh bkl pesen lagi aaaaaa love you ❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️
# --------------------------------------------------------------------------------
# Setau aku ini bukan tosca tp lebih ke ijo muda soalnya wrnanya sma dgn tembok aku yg ijo muda😭 niatnya mau samaan sma suami dan anak eh yg dtg wrnanya ga sesuai harapan, entah mungkin aku yg salah beli😭😭 bahannya dipake nya si kayanya panas sesuai hargalah klau untuk itu.
# --------------------------------------------------------------------------------
# Tampilan:sesuai
# Warna:sesuai
#
# Warnanya hampir mirip baju pramuka
# --------------------------------------------------------------------------------
# Alhamdulillah barangnya bagus dan cocok karena barangnya sudah diterima oleh orang lain
# --------------------------------------------------------------------------------
# Kecewa banget sama barang.nya.. Itu sih bukan warna coksu tapi warna coklat pramuka.. Dan dibaju.nya juga gak ada merk apa", itu baju seragam pramuka cuma dikasih gantungan lebel wys sama diganti kancing.nya warna item ajahh
# --------------------------------------------------------------------------------
# Tampilan:gk sesuai foto penjualan
# Warna:bagus
#
# Kayak baju yang harga 35an
# Harga segitu gk sesuai ekspektasi
# --------------------------------------------------------------------------------
# Tampilan:biasa
# Warna:sesuai
#
# Lumayan ...sesuai sama harganya
# --------------------------------------------------------------------------------
# Kata temenku barang nya bagus , kualitas nya baik , pengiriman nya juga cepet. Maaf fotonya tidak sesuai produk
# --------------------------------------------------------------------------------
# Tampilan:bagus
# Warna:sesuai deskripsi....bagus
#
# Kualitas baik....ga mengecewakan....top seller
# --------------------------------------------------------------------------------
# Harga : murah
# Kualitas : lumayan bagus untuk harga segitu
# Size : pas sesuai pesanan
# --------------------------------------------------------------------------------
# kualitas produk sangat baik, harga produk sangat baik, kecepatan pengiriman baik
# --------------------------------------------------------------------------------
# Tampilan:bagus kainnya
# Warna:sesuai
#
# Kainnya bagus . Warna sesuai..
# --------------------------------------------------------------------------------
# Tampilan:mantap
# Warna:sesuai
#
# Bikin nambah ganteng aku aja
# --------------------------------------------------------------------------------
# Pengemasan rapi, pengiriman cepat dan kain nya lumayan bagus
# --------------------------------------------------------------------------------
# Respon penjual baik , barang sesuai gambar,
# --------------------------------------------------------------------------------
# Sipp okelah, bahan juga standar ngga yg panas2 bgt kayaknya.
#
# Cuman untuk pria dewasa mending pilih XL ikurannya
# --------------------------------------------------------------------------------
# Pesanan sudah sampai packing rapi barang jahitan benang keluar semua kelihatan terburu-buru cepat selesai ukuran XL tapi koq spt L
# --------------------------------------------------------------------------------
# Maaf foto tidak sesuai , bajunya bagussss bahan nya juga lumayan , saya pesen biru Terima kasih yaaaaa
# --------------------------------------------------------------------------------
# Barang bagus sesuai di foto warnanya, tpi ngepas di badan. Walaupun ukuran nya besar..
# --------------------------------------------------------------------------------
# Tampilan:bagus
# Warna:coksu L
#
# Lumayan bagus kemejanya dengan harga segituu gak nyesel beli
# --------------------------------------------------------------------------------
# Barangny bagus
# Harga terjangkau
# Tanteku suka
# Next bakal order lg
# Thx shopee, thx seller
# --------------------------------------------------------------------------------
# Alhamdulillah bagus n pelayanan kakaknya juga baik
# Makasih ya kk bisa dibawa pulkam bajunya
# --------------------------------------------------------------------------------
# Bgus bhn. Lumayan utk sehari-hari. Nyampenya cpt jga. Terima kasih.
# --------------------------------------------------------------------------------
# Pengirimn cepet.. bagus gak tebel gak tipis pas lah buat harga segitu.
# --------------------------------------------------------------------------------
# Kualitas produk sangat bagus bahannya juga adem gx nyesel belanja disini okee lah
# --------------------------------------------------------------------------------
# Tampilan:bagus
# Warna:ok
#
# Belum du coba semoga muat 😁😁
# --------------------------------------------------------------------------------
# Packing agak lama ya, pengiriman cepat..
# Baju real pict...
# --------------------------------------------------------------------------------
# Tampilan:mayan
# Warna:pramuka
#
# Terimakasih baju pramukanya sudah diterima
# --------------------------------------------------------------------------------
# Paketnya Dateng Alhamdulillah bagus dan responnya juga baik banget 😉
# --------------------------------------------------------------------------------
# Lumayan kainnya dg harga terjangkau bisa ngasih THR pamanku 🥰
# --------------------------------------------------------------------------------
# Puas banget belanja disini
# manteb..siipp...walau kemarin sempet salah ukuran tapi seller tanggung jawab dan fast resp
# suka banget...realpict juga...
# bisa jadi langganan
# --------------------------------------------------------------------------------
# Pesean udah di terima sama orang rumah.. blm di liat juga barang nya... Semoga toko nya amanah lah... Kurir nya ramah juga... Trimakasih..
# --------------------------------------------------------------------------------
# Barang sesuai , pengemasan cepat , kalau milih L sebaiknya dilebihi XL soalnya ini ukuran standart tidak besar
# --------------------------------------------------------------------------------
# Agak tipis kainya semoga dpke g panas,pngiriman dan packing okee lah...thx kak
# --------------------------------------------------------------------------------
# Lumayanlah sesuai Harga
# Tapi masalah ukuran.
# XL tapi kek Ukuran L.
# Pengiriman cepat.
# --------------------------------------------------------------------------------
# Tampilan:bahannya bagus trs nyaman di pakai pokoke joss buat penjualnya sukses selalu.
# --------------------------------------------------------------------------------
# Kemeja nya oke cuma rada kecil uk nya tpi tetep puas sama barangnya
# --------------------------------------------------------------------------------
# Ok bahan lumayan sih oke...  Gk ada lanbel nya 😀
# --------------------------------------------------------------------------------
# Gak seauai ukuran, yg krem kecil... Selisih 1 cm dari yang grey.. bahan biasa aja ternyata.. pas puasa gini sih masih muat.. ntar abis lebaran gak bakalan cukup..
# --------------------------------------------------------------------------------
# Maaf fotonya ngak sesuai ,, bahanya lumayan tapi dengar harga segitu harusnya bahan juga agak baguslah biar pembeli juga senang, warna baju yg di pesan sama yang dtang juga ngak trll sama
# --------------------------------------------------------------------------------
# Produk oke..bahan jg oke..👍🏻💖💯🙏🏻😁
# --------------------------------------------------------------------------------
# Maaf gak keburu ke foto,,karna keburu dibawa custamerku....barang sesuai harga..agak tipis ...tapi gpp lumayan
# --------------------------------------------------------------------------------
# ko kaya sragam anak sekolah yah tipis+panas walupun dibandrol harganya 399 aku gk yakin dgn harga segitu bahanya jelek
# --------------------------------------------------------------------------------
# Tampilan:biasa saja
# Warna:biasa
#
# Mirip mirip Seragam pramuka ternyata. tapi selebihnya bagus
# --------------------------------------------------------------------------------
# Bintang 4 aja. Barang sesuai gambar. Tapi sayang ukuran xl nya kecil.. 😔
# --------------------------------------------------------------------------------
# Warna kemeja sgt sesuai dg di foto tp utk jaritan kurang rapi
# --------------------------------------------------------------------------------
# Aku kasih 4 bintang dengan harga segitu bahannya kasar dan kaku kainnya
# --------------------------------------------------------------------------------
# Kecewa..harga segitu bahan dan warna seperti baju pramuka...😒
# --------------------------------------------------------------------------------
# Warna:coksu
#
# Kain tipis.. g sesuai produk di gambar
# --------------------------------------------------------------------------------
# Tampilan:bagus
# Warna:hitam
#
# Ukuran xl y agk kecil
# --------------------------------------------------------------------------------
# Semuanya okeee.... deh....👍
# Terima kasih semuanya....🥰
# --------------------------------------------------------------------------------
# Realpict
# owner ramah
# sesuai deskripsi
# alhamdulillah puas belanja disini
# --------------------------------------------------------------------------------
# Terima kasih, paket kemeja sudah sampai, semoga awet. vhfhcbv
# --------------------------------------------------------------------------------
# Pesanan sdh datang barang bagus bnget
# --------------------------------------------------------------------------------
# Tampilan:lumayan
# Warna:bagus
#
# Ukuran belu di coba
# --------------------------------------------------------------------------------
# 💰TABUNGAN TARGET VIRAL💰
#
# 👇🏻Ukuran
# Diameter 8CM + Tinggi 14CM
# Bahan Dasar Papertube
# Body Lapis Art Paper
#
# 💸12k
# --------------------------------------------------------------------------------
# Produk bagus,pengiriman juga cepat
# --------------------------------------------------------------------------------
# Bgus bhan.y toko.y amanah👍👍👍mks soopy
# --------------------------------------------------------------------------------
# Tampilan:kemeja
# Warna:coksu
#
# terimqkasih paket nya udah sampe..bagus banget..semoga makin lancar dan berkah isahanya
# --------------------------------------------------------------------------------
# Bahannya baguss bngett tpi agak tipis
# --------------------------------------------------------------------------------
# bagus banget baju nya udh nyampai dengan cepat pokonya thebest makasi seller😍😍
# --------------------------------------------------------------------------------
# Tiada usaha yg tnp hasil.alhamdulilah sll bljr untuk memperbaiki dan tentuny bljr sabar agr bs menerima komplin  penilaian dr costumer " lainy.mksh ka respony .mg brkh lncr barokah
#
# --------------------------------------------------------------------------------
# Ammmmmmmmmmmm.............
# Pokok nya mksiiiiiih yuuuuuuups
#
# Cepeeeeet juga...
# --------------------------------------------------------------------------------
# Tampilan:mayan
# Warna:sesuai
#
# Terimakasih
# --------------------------------------------------------------------------------
# Bahan bagus..
# Harga terjangkau
# Pengiriman cepat
# --------------------------------------------------------------------------------
# Suka banget 😍 respon penjual cepet n baik ☺
# --------------------------------------------------------------------------------
# Barang bagus ,asli tebal ,bisa jadi langganan di toko ini ,trimakasih 🙏
# --------------------------------------------------------------------------------
# Kemejanya bagus lumayan buat Adek saya lebaran suka semoga laris manis tokonya kak abschkdyllvlvluagdryoalfhka
# --------------------------------------------------------------------------------
# Pengiriman nya cepat tapi gak tau produknya gimana soalnya udah diambil sama yang punya
# --------------------------------------------------------------------------------
# Terima kasih..... warnax kurang srek... terima kasih mas kurir selalu setia ngirim punya saya
# --------------------------------------------------------------------------------
# Ukurannya kecil..ga sesuai standar XL Internasional jadinya ga kepake Krn kekecilan.
# --------------------------------------------------------------------------------
# Bahanya sedikit kasar,tapi bagus👍🏻maaf video nya random
# --------------------------------------------------------------------------------
# bagus si, tetapi ukuranya L kekecilan buat orang dewasa 😄
# --------------------------------------------------------------------------------
# Alhamdulillah sudah sampai
# Terimakasih reseller bagus pas dengan harga segitu
# --------------------------------------------------------------------------------
# Barang bagus sesuai dgn pesanan.....pengiriman banyak lambat
# --------------------------------------------------------------------------------
# Peroduknya sangaltah oke sekali pokoknya jos pokoknya mantap
# --------------------------------------------------------------------------------
# Tampan kayaknya aldebaran😊😆
# Semoga selalu amanah kedepannya
# --------------------------------------------------------------------------------
# Bahan bagus
# --------------------------------------------------------------------------------
# Baju nya bagus suami sayah suka makasih kk
# --------------------------------------------------------------------------------
# Tampilan:bagus
# Warna:sesuai
# --------------------------------------------------------------------------------
# Pas dan bahannya bagus 👍
# --------------------------------------------------------------------------------
# Ckep bngt sh cuma warna nya terlalu terang
# --------------------------------------------------------------------------------
# Alhmdllah udah nyampe, smoga cocok yg punyanya soalnya pesenan teman 😊
# --------------------------------------------------------------------------------
# 2 hari paketan udah nyampe.. barang bagus
# --------------------------------------------------------------------------------
# Agak tipis tp bagus 👍
# --------------------------------------------------------------------------------
# Tampilan:bagus
# Warna:oke
# --------------------------------------------------------------------------------
# Alhamdulillah udah sampai cocok seperti harapan sukses dach??...
# --------------------------------------------------------------------------------
# Alhamdulillah paket ny udh Dateng semoga cocok👍
# --------------------------------------------------------------------------------
# Mantap lah dengan harga segitu
# --------------------------------------------------------------------------------
# Bagus tidak mengecewakan jossss mantappp pokok e puassssssss termurah
# --------------------------------------------------------------------------------
# Bagus unt harga segitu kainnya lumayan tebelll
# --------------------------------------------------------------------------------
# Tampilan:baik
# Warna:baik
# --------------------------------------------------------------------------------
# Tampilan:oke
# Warna:oke
# --------------------------------------------------------------------------------
# Barang bagus, paking rapi. 👍👍
# --------------------------------------------------------------------------------
# Pengiriman cepat ,bajunya mantap
# --------------------------------------------------------------------------------
# Barangnya bagus,pengiriman cepet
# --------------------------------------------------------------------------------
# Tepat sasaran
# --------------------------------------------------------------------------------
# Cocok banget sama ayang :D sukak 🥰❤️
# --------------------------------------------------------------------------------
# Tampilan:lumayan
# Warna:sesuai dengan gambar
# --------------------------------------------------------------------------------
# Lumayan lah dengan harga segitu sesuai harga❤
# --------------------------------------------------------------------------------
# Karena di pake nyaman ,bahan nya dingin
# --------------------------------------------------------------------------------
# Tampilan:elegan
# Warna:hitam,L
# --------------------------------------------------------------------------------
# Tampilan:mantap
# Warna:abu tua
# --------------------------------------------------------------------------------
# Tampilan:bagus
# Warna:sesuai pilihan
# --------------------------------------------------------------------------------
# Kualitas baju lumayan lah sesuai harga.
# --------------------------------------------------------------------------------
# Sesuai gambar . Bahannya bagus banget 😍😍
# --------------------------------------------------------------------------------
# Harga sgitu mantap lah,,ga mengecewakan
# --------------------------------------------------------------------------------
# Paket sampai dengan selamat dan baik
# --------------------------------------------------------------------------------
# Warna:sesuai
# Tampilan:bagus
# --------------------------------------------------------------------------------
# Bahannya bagus & sesuai dengan harganya
# --------------------------------------------------------------------------------
# Bgus jahitan rapi top bangett
# --------------------------------------------------------------------------------
# bagus .. pengiriman sgt cepat
# --------------------------------------------------------------------------------
# Tampilan:bangnya.XXL tapi kecil,tulisan polpin
# --------------------------------------------------------------------------------
# Ukuran L nya seperti ukuran M, terlalu kecil
# --------------------------------------------------------------------------------
# kain nya jelekkk bgt .kayak kain pramuka
# --------------------------------------------------------------------------------
# Tampilan:sesui
# Warna:sesuai
#
# Bagus
# --------------------------------------------------------------------------------
# Warna cream nya beda sama d gambar
# --------------------------------------------------------------------------------
# Umm pas di suami harga sesuai
# --------------------------------------------------------------------------------
# Coksu nya seperti seragam Pramuka 🥺
# --------------------------------------------------------------------------------
# baju coklatnya kyak baju pramuka 🤣
# --------------------------------------------------------------------------------
# Terimakasih shope
# terimakasih seler
# Barang baik
# --------------------------------------------------------------------------------
# Kurir kurang ramah bintang satu ⭐
# --------------------------------------------------------------------------------
# Warna:krem,L
#
# Memuaskan
# --------------------------------------------------------------------------------
# Kek baju Pramuka 😁 yang coksu
# --------------------------------------------------------------------------------
# Ukuran XL nya terlalu kecil
# --------------------------------------------------------------------------------
# Tipis bgt yaa bahan nya
# --------------------------------------------------------------------------------
# Warna nya gak sesuai poto
# --------------------------------------------------------------------------------
# Alhamdulillah Real pict.. maaf nda sempat foto min soalnya brgnya langsung dikirim ke kampung.
# --------------------------------------------------------------------------------
# Terimakasih barang sudah di terima baik, kwalitas bahan halus cukup bagus,sesuai dengan pesanan, pengiriman baik, packing baik 👍
# --------------------------------------------------------------------------------
# Sepadan dengan Uang:sesuai
# Styling:sesuai
# Pas untuk Acara:sesuai
#
# sesuai
# --------------------------------------------------------------------------------
# Sepadan dengan Uang:iya
# Styling:mantab
# Kualitas:kain tipis
# --------------------------------------------------------------------------------
# Pas untuk Acara:ya
# Sepadan dengan Uang:iya
# Kualitas:baik
# --------------------------------------------------------------------------------
# Sepadan dengan Uang:pengiriman cepat mudah" han awet 🤲🤲
# --------------------------------------------------------------------------------
# Saran Tampilan:Sudah bagus dan simple
# Kualitas:Kainnya bagus, agak menyerap keringat, dingin
# Kenyamanan:Halus nyaman di kulit
#
# Bajunya bagus, tidak ada cacat sedikitpun pada kainnya
# Seller fast respon, pelayanan juga baik
# Pengiriman juga cepat dan tepat
# Semoga tokonya berkah dan amanah selalu
# Terimakasih 🙏🏻😊
# --------------------------------------------------------------------------------
# Kualitas:bagus
# Saran Tampilan:Alhamdulillah cocok sesui
# Pas untuk Acara:sesuai
#
# Sesuai harapan semoga pas 🤭🤭🤭
# --------------------------------------------------------------------------------
# Styling:bahan mengecewakan
#
# kain tipis agak trawang
# --------------------------------------------------------------------------------
# Styling:keren, simple
# Kualitas:lumayan, kain tidak terlalu gerah
# Pas untuk Acara:buka bersama, karena saya beli ini untuk buka bersama🤣
# --------------------------------------------------------------------------------
# Styling:cocok dibuat segala umur
# Pas untuk Acara:pas dipake segala acara
# --------------------------------------------------------------------------------
# Styling:Jahitannya bagus dan keliatan kokoh
# Kenyamanan:Bahannya rada kasar ya. Kukira bahan halus. Warnanya cukup kusam but gapapa sih masih bisa dipake
#
# Di gambar warna hitamnya glowing pas sampai kusam. But no problem sih masih bisa dipake. Jahitan dan potongan kece sebenarnya.
# --------------------------------------------------------------------------------
# Styling:alhamdulillah sesuai dgn harga
# Kenyamanan:lumayan
# Pas untuk Acara:sipppp
# --------------------------------------------------------------------------------
# Kualitas:cukup baik
# Saran Tampilan:engga bisa ngasih saran hehe
# Styling:bagus
#
# Ok bagus dah jos pengiriman cpt
# --------------------------------------------------------------------------------
# Bahan bagus tidak panas tidak mudah kusut, ukuran sebaiknya naikan satu ukuran dari ukuran biasa krn seperti slim fit
# --------------------------------------------------------------------------------
# Sepadan dengan Uang:sepadan dengan harga
# Pas untuk Acara:kondangan
#
# Suka banget sama kemajanya pas ukurannya recommended banget lah pokoknya
# --------------------------------------------------------------------------------
# Kualitas:bagus
# Pas untuk Acara:formal / non formal
# Kenyamanan:nyaman
#
# Alhamdulillah paketnya udh sampe sebelum lebaran pengiriman cepet kemeja nya bagus dan pas di suami aku
# --------------------------------------------------------------------------------
# Saran Tampilan:bagus
# Styling:bagus
# Sepadan dengan Uang:sesuai..
# --------------------------------------------------------------------------------
# Pas untuk Acara:pormal
# Styling:ok
# Saran Tampilan:kwalitas bagus
# --------------------------------------------------------------------------------
# Bahan nya kasar trnyta, kirain halus sedikit kecewa sihh
# --------------------------------------------------------------------------------
# Sepadan dengan Uang:untuk harga juga sangat bagus dan ramah di kantong
# Kualitas:kualitas kain bagus, nyaman dipakai cuma minus di size kurang panjang dikit, tapi tetap good lah
# --------------------------------------------------------------------------------
# Kualitas:biasa
# Saran Tampilan:perbaiki
# Kenyamanan:lumayan
#
# ku kira dengan harga segitu bisa lah yaa dpat yg agak bagusan kualitas nya trnyata ndak sesuai ekspektasi.. kain tipis, beli 2 yg satu agak tebel yg 1 tipis banget.. haduh smoga CS sya suka deh
# --------------------------------------------------------------------------------
# Kenyamanan:Sedang
# Pas untuk Acara:Harian
# Sepadan dengan Uang:75000
#
# Lumayan. Sesuai harga
# --------------------------------------------------------------------------------
# Kemeja yang dipesan sudah sampai. Pengiriman cepat, ukurannya pas di badan, kualitas bahan memuaskan dan pengiriman cepat.
# --------------------------------------------------------------------------------
# Kualitas:bagus
# Pas untuk Acara:semua acara
# Styling:simple
#
# Meskipun murah.sumpah ini nyaman di pake.nya sama pak su, kainnya dingin nyerap keringat, insyaallah beli lagi klo butuh warna yg lain,
# --------------------------------------------------------------------------------
# Kualitas:baik
# Pas untuk Acara:keluarga dan kondangan
# Kenyamanan:sangat nyaman dipakai
#
# Barang sangat bagus,,, dan sesuai dengan yg di gambar... Mantap min 👍
# --------------------------------------------------------------------------------
# Kainnya kurang bagus terlihat seperti kemeja murah
# --------------------------------------------------------------------------------
# Barang sudah sampai,... Sesuai orderann semoga muat dan nyaman dipakai terima kasih
# --------------------------------------------------------------------------------
# Saran Tampilan:oke
# Sepadan dengan Uang:iya
# Kualitas:bagus
#
# Ukuran pas nyaman di pake
# --------------------------------------------------------------------------------
# Styling:oke
# Saran Tampilan:acara informal n santai
# --------------------------------------------------------------------------------
# Kualitas:standar
# Kenyamanan:sangat nyaman
# Pas untuk Acara:lebaran
#
# Lumayan
# --------------------------------------------------------------------------------
# Pas untuk Acara:lumayan
# Kualitas:lumayan
# Sepadan dengan Uang:lumayan
#
# kain nya tipis kasar
# --------------------------------------------------------------------------------
# Kualitas:gk realpck
#
# Kecewa, kain tipis, hrga 75rb, dpt promo jd 67, tp kyk bli di psar hrga 35 ribuan
# Kpok gk mau bli lgi👎👎
# --------------------------------------------------------------------------------
# Alhamdulillah paket nya udah sampe kemarin datang 1 terus chat reseller nya Alhamdulillah amanah dan terpercaya bahan nya bagus terima kasih sebanyak banyak nya tokok nya amanah banget pokok nya 😘😘😘🙏🙏🙏
# --------------------------------------------------------------------------------
# Saran Tampilan:baik
# Pas untuk Acara:nyantai
# Kualitas:lumayan lah
#
# Barang dah sampai pas mantap
# --------------------------------------------------------------------------------
# Sepadan dengan Uang:sepadan
# Saran Tampilan:lumayan
# Kenyamanan:nyaman
#
# Baju lumayan bagus...hanya saja terlalu kecil ukurannya
# --------------------------------------------------------------------------------
# Pas untuk Acara:formal
# Kualitas:top
# Styling:ok
#
# Bagus
# --------------------------------------------------------------------------------
# Saran Tampilan:lumayan
# Pas untuk Acara:formal
# Kenyamanan:lumayan
#
# Semoga jadi langganan terus, kurir baik
# --------------------------------------------------------------------------------
# Sepadan dengan Uang:gak
#
# Bahannya tipis banget nerawang lagi ,ga sesuai harga
# --------------------------------------------------------------------------------
# Kualitas:buruk
# Saran Tampilan:buruk
# Styling:buruk
#
# XL ukurannya kecil parah
# --------------------------------------------------------------------------------
# Pas untuk Acara:resmi
# Kenyamanan:semoga nyaman
# Kualitas:seperti nya bahan nya tipis, agak panas tp bagus lah untuk dipake
#
# Sepertinya kekecilan
# --------------------------------------------------------------------------------
# Pas untuk Acara:resmi
# Kualitas:bagus poll
#
# Cukup bintang yg berbicara👍
# Bagus banget pokoknya
# Maaf g sempet foto..
# --------------------------------------------------------------------------------
# Respon penjual cepat
# Pengiriman cepat
# Barang sesuai pesanan
# Mantap
# --------------------------------------------------------------------------------
# Pas untuk Acara:formal
# Sepadan dengan Uang:sepadan
# Kenyamanan:nyaman
#
# Bagus sekali kemejanya, bahan adem dan tebal, cocok untuk acara formal, pengemasan dan pengiriman cepat, rekomended ya gaess
# --------------------------------------------------------------------------------
# bahannya terlalu tipis untuk harga segitu,apalagi untuk warna hitam
# --------------------------------------------------------------------------------
# Pas untuk Acara:semua
# Kualitas:bagus
# Saran Tampilan:keren
# --------------------------------------------------------------------------------
# Styling:keren
# Kenyamanan:oke
# Pas untuk Acara:lebaran
#
# Alhamdulillah paketnya sudah sampai,,terima kasih banyak
# --------------------------------------------------------------------------------
# Saran Tampilan:oke
# Kualitas:oke
# Kenyamanan:oke
#
# Pengiriman cepat packaging aman rapi gak ada cacat. Thank you🤍
# --------------------------------------------------------------------------------
# Kenyamanan:kurang XL
# Kualitas:standart
# Styling:biasa saja
#
# Tidak sesuai foto.
# --------------------------------------------------------------------------------
# Saran Tampilan:bagus
# Pas untuk Acara:nikahan mantan
# Kualitas:not bad lah
#
# Pengiriman cepat. Kapan kapan order lagi
# --------------------------------------------------------------------------------
# Barang sesuai pesanan,trimakasih shoppy,makasi seller
# --------------------------------------------------------------------------------
# Kualitas:kain agak tipis tapi bagus sih
# Pas untuk Acara:formal
# Saran Tampilan:lumayan
# --------------------------------------------------------------------------------
# Pas untuk Acara:sangatnjelek tak sesuai yg gi foto.
#
# BAJU2 YG ONLINE YG OERBAH SAYA BELI SEJAUH INI SEMUANYABSANGAT JELEK
# --------------------------------------------------------------------------------
# Pas untuk Acara:badan
# Styling:oke
# Sepadan dengan Uang:pas
# --------------------------------------------------------------------------------
# Kenyamanan:adem, lembut
# Sepadan dengan Uang:cocok
# Styling:keren
#
# Mantap dari segi packing aman, respon penjual, dan pengiriman cepat semuanya mantap
# --------------------------------------------------------------------------------
# Kualitas:bagus
# Sepadan dengan Uang:sesuai dengan harga
#
# Baju nya pas terimakasih 👍
# --------------------------------------------------------------------------------
# Sepadan dengan Uang:lumayan dg harga sgitu
# Pas untuk Acara:main
# --------------------------------------------------------------------------------
# Sepadan dengan Uang:harga sesuai Sama Isi Dompett👌
# Saran Tampilan:Josss Pokok e😉🤩
# --------------------------------------------------------------------------------
# Styling:yoi
# Saran Tampilan:kya agung botak
# Kenyamanan:ok
#
# Alhamdullah barang sudah sampai dengan selamat dan semoga sukses selalu buat seler
# --------------------------------------------------------------------------------
# Sepadan dengan Uang:sedikit kekecilan tapi produk bagud
# --------------------------------------------------------------------------------
# Styling:bagusss
# Pas untuk Acara:acara apa saja pas lah untuk dioakai kemejanya
# --------------------------------------------------------------------------------
# Kenyamanan:lumayan
# Styling:keren
# Pas untuk Acara:resmi
#
# Beli spearpart di toko kami aja
# --------------------------------------------------------------------------------
# Sepadan dengan Uang:nice
# Saran Tampilan:good
# Kenyamanan:good
#
# mantapppp lah
# --------------------------------------------------------------------------------
# Kualitas:Oke
# Kenyamanan:Baik
# Sepadan dengan Uang:Ya
# --------------------------------------------------------------------------------
# Sepadan dengan Uang:Oke
# Pas untuk Acara:Formal
#
# Pembeli tidak memberikan kritikan apapun
# --------------------------------------------------------------------------------
# Kualitas:baik
# Pas untuk Acara:kerja, nikahan, holiday
# --------------------------------------------------------------------------------
# Saran Tampilan:barang ok
#
# Pengiriman cepat dan barangnya sangat bagus
# --------------------------------------------------------------------------------
# Pengiriman cepat dan barang sampai dengan aman, kualitas bagus bner utk harga segitu 👍👍
# --------------------------------------------------------------------------------
# Saran Tampilan:kain tipis banget ..gampang lecek dan susah disetrika.. kayak harga 30an
# --------------------------------------------------------------------------------
# Kualitas:bagus
# Pas untuk Acara:jln2
#
# trimakasih, shope, bagus dan cepat, bintang 5
# --------------------------------------------------------------------------------
# Pas untuk Acara:resmi
# Saran Tampilan:standar
# Styling:lumayan baik
#
# Kualitas cukup baik
# --------------------------------------------------------------------------------
# Kualitas:bagus
#
# Bahab halus gak nerawang, cocok untuk lebaran
# --------------------------------------------------------------------------------
# Saran Tampilan:sip
# Styling:ok
# Kualitas:baik sesuai dgn harga
# --------------------------------------------------------------------------------
# Kualitas:baik
# Saran Tampilan:bagus
# Kenyamanan:baik
#
# Sesuai harga
# --------------------------------------------------------------------------------
# Kualitas:biasa
# Sepadan dengan Uang:kurang harga segini ke Bhan harga 30rb an
# --------------------------------------------------------------------------------
# Tengkyuu 🥰
# Kirain gak akan Dateng lagi soal nya dari kemarin ditungguin gak dateng².. it's oke baju nya suka cocok buat suami☺️🙏
# --------------------------------------------------------------------------------
# Kenyamanan:Bahan tipis dan kasar
# Saran Tampilan:lumayan
# Kualitas:Kurang bagus tidak sesuai dg yg ada di foto
#
# Bahan panas, kasar dan tipis
# --------------------------------------------------------------------------------
# Sepadan dengan Uang:tidak sepadan dengan uang,seharusnya harga 1/2 dari harga barang
# Kenyamanan:nyaman
# Saran Tampilan:baik
#
# Kain terlalu tipis untuk harga sekian,tidak sesuai ekspetasi dan rating yang ada, saran untuk admin untuk lebih mementingkan kualitas produknya
# --------------------------------------------------------------------------------
# Kualitas:lumayan
# Kenyamanan:okelah
#
# Mendarat dengan selamat , cuma bahannya GK nyerep keringat sih , tapi gapapa semuahnya bagus jahitan rapih next order , pengiriman juga cepet thank you 👍👍
# --------------------------------------------------------------------------------
# Tangannya kepemdekan, salah milih ukuran atau emg modelannya kya gtu si?
# --------------------------------------------------------------------------------
# XXL tapi sempit kayak L, ukuran cuma ditulis biar dikira XXL
# --------------------------------------------------------------------------------
# Kenyamanan:ok
# Sepadan dengan Uang:ok
# Pas untuk Acara:ok
# --------------------------------------------------------------------------------
# Barang bagus tapi salah kirim ukuran..
# Pesan xxxl di kirim xxl
# --------------------------------------------------------------------------------
# Saran Tampilan:Bagus
# Kualitas:Bagus
# Kenyamanan:Nyaman
# --------------------------------------------------------------------------------
# Kualitas:bagus
#
# Bagus , ukuranya pas pengiriman cepat
# --------------------------------------------------------------------------------
# Kualitas:barang ok
# Styling:ok
# Kenyamanan:lumyan
#
# Smua sesuai dgn pesanan...mksh☺️🙏
# --------------------------------------------------------------------------------
# Sepadan dengan Uang:sesuai harga
# Pas untuk Acara:santay dan ngantor
# Saran Tampilan:ok
# --------------------------------------------------------------------------------
# Kualitas:baik
# Sepadan dengan Uang:oke
# Saran Tampilan:baik
#
# Sangat bagussssssssssss sekaliiijjkkkjbzbzbznNNNnnNNNNNnNnb       hahahahajakakjssjsnsnnN
# --------------------------------------------------------------------------------
# Paket sdh datang, dan di terima dlm kondisi baik, barang sesuai pesanan
# Terima ksih shope, seller & kurir nya, 👍👍👍
# --------------------------------------------------------------------------------
# Kenyamanan:ok
# Styling:y
# Sepadan dengan Uang:y kena
# --------------------------------------------------------------------------------
# pas nyampe ada kek bolong gitu yang ngemas sambil ngerokok apa ya?
# --------------------------------------------------------------------------------
# Kecewa beli, ternyata kainnya sangat tipis
# Warna tidak sesuai dengan foto
# --------------------------------------------------------------------------------
# Sepadan dengan Uang:bahannya kasar kaya baju serba 35an aku kecawa banget
# --------------------------------------------------------------------------------
# Paket baru tadi sampai sesuai dengan pesanan bahan halus agak tipis jahitan rapih warna sama dengan gambar pokok nya bagus mksih seller dan kurir yg mengantar
# --------------------------------------------------------------------------------
# Sudah sampai plastik nya beda dalam jg gk ada kertas penyanggah bju untuk pelanggan ku semoga puas dan suka.
# --------------------------------------------------------------------------------
# Pas untuk Acara:segala.acara
# Kualitas:cukup
# Sepadan dengan Uang:sepadan
#
# barang telah mendarat dengan selamat sampai tempat,barang sesuai dengan contoh pokoe mantul dah mantaf betul,..
# --------------------------------------------------------------------------------
# Sepadan dengan Uang:lumayan
# Pas untuk Acara:lebaran
# Kualitas:baik
#
# Barang sudah diterima dengan baik, tingkat kan selalu kualitas, sukses selalu untuk toko nya,sippp
# --------------------------------------------------------------------------------
# Pengiriman cepat, harga murah.. Kualitas lumayan, tp XL kecil
# --------------------------------------------------------------------------------
# Kenyamanan:lumayan
# Styling:ok
# Pas untuk Acara:kondangan
#
# Dari segi bahan lumayan jahitan rapih tapi untuk ukuran xxl ny masih kurang besar seperti ukuran xl jadi masih ngepres di badan.
# --------------------------------------------------------------------------------
# Saran Tampilan:bagus
# Styling:keren
# Sepadan dengan Uang:sesuai dengan harganya
# --------------------------------------------------------------------------------
# Sepadan dengan Uang:sepadan
# Kualitas:lumayan
#
# Bgus pengirimanya
# --------------------------------------------------------------------------------
# Kualitas:baik
# Pas untuk Acara:resmi dan santai
#
# Kemeja sudah datang, bahan lumayan tebal. Pengiriman juga cepat. Unk harga segitu sudah oke
# --------------------------------------------------------------------------------
# Saran Tampilan:cukup bagus
# Sepadan dengan Uang:kalau sama harga iya sesuai sih
# Styling:cukup bagus kok
# --------------------------------------------------------------------------------
# Kualitas:jahitan rapi cocoklah  sesuai hrg
# ...
# Luar biasa
# --------------------------------------------------------------------------------
# Terima kasih
# --------------------------------------------------------------------------------
# real pic
# --------------------------------------------------------------------------------
# Bahan tipis
# --------------------------------------------------------------------------------
# Terbaik pokoknya
# --------------------------------------------------------------------------------
# Mntp lah
# --------------------------------------------------------------------------------
# Lumayan tipisss
# --------------------------------------------------------------------------------
# Sip cocok
# --------------------------------------------------------------------------------
# Ok bgt
# --------------------------------------------------------------------------------
# Lumayan sih
# --------------------------------------------------------------------------------
# Jeren
# --------------------------------------------------------------------------------
# Bagus
# --------------------------------------------------------------------------------
# Mantul
# --------------------------------------------------------------------------------
# tipis
# --------------------------------------------------------------------------------
# Bagus
# --------------------------------------------------------------------------------
# Mksih
# --------------------------------------------------------------------------------
# 👍
# --------------------------------------------------------------------------------
# Bagus
# --------------------------------------------------------------------------------
# Baguslah
# --------------------------------------------------------------------------------
# Oke
# --------------------------------------------------------------------------------
# Mantullllll
# --------------------------------------------------------------------------------
# Bagsu
# --------------------------------------------------------------------------------
# Mayan
# --------------------------------------------------------------------------------
# Bagus
# --------------------------------------------------------------------------------
# Lumayan
# --------------------------------------------------------------------------------
# Lumayan
# --------------------------------------------------------------------------------
# Bahanya tipis
# --------------------------------------------------------------------------------
# Bahan panas
# --------------------------------------------------------------------------------
# Bagus bgt realpict
# --------------------------------------------------------------------------------
# Saran Tampilan:ok
# Pas untuk Acara:ok
# --------------------------------------------------------------------------------
# Jahitan di bagian ketiak kurang rapi.
# --------------------------------------------------------------------------------
# Styling:lumayan
# Kualitas:baik
# --------------------------------------------------------------------------------
# Sesuai harga, stsndart
# --------------------------------------------------------------------------------
# Utk ukuran pilih 2 no diatas size kita
# --------------------------------------------------------------------------------
# Bahan adem cuma agak tipis
# --------------------------------------------------------------------------------
# Pas untuk Acara:bagus
# --------------------------------------------------------------------------------
# Styling:ok
# Saran Tampilan:bagus
#
# Semua
# --------------------------------------------------------------------------------
# Kualitas:bagus
# Pas untuk Acara:resmi
# Styling:pas
# --------------------------------------------------------------------------------
# Minta hitam datang biru. Bahan kurang bagus
# --------------------------------------------------------------------------------
# Menurut saya bahan y terlalu tipis ..
# --------------------------------------------------------------------------------
# Kualitas:Baik
# Kenyamanan:Baik
#
# Bagus bajunya
# --------------------------------------------------------------------------------
# Saran Tampilan:ok
# Styling:ok
# Kualitas:lumayan
# --------------------------------------------------------------------------------
# Bahan lumayan nyaman dipakai
# --------------------------------------------------------------------------------
# Blm di buka semoga bagus ....
# --------------------------------------------------------------------------------
# Kemejanya bagus next beli lagi
# --------------------------------------------------------------------------------
# Kualitas:ok
# Styling:ok
# Saran Tampilan:ok
#
# Ok
# --------------------------------------------------------------------------------
# Kerenn
# --------------------------------------------------------------------------------
# Barangnya bagus
# --------------------------------------------------------------------------------
# Bagus
# --------------------------------------------------------------------------------
# Barang ok cocok.
# --------------------------------------------------------------------------------
# Kualitas:recomended
# --------------------------------------------------------------------------------
# Kualitas:pas cuman aga tipis tapi baguss
# --------------------------------------------------------------------------------
# Pas untuk Acara:ramadhan
#
# Bahan nya agak tipis
# --------------------------------------------------------------------------------
# Saran Tampilan:bagus
# --------------------------------------------------------------------------------
# Sprtinya bagus
# --------------------------------------------------------------------------------
# B aja..
# --------------------------------------------------------------------------------
# Kualitas:bagus
# Styling:keren
# --------------------------------------------------------------------------------
# Kualitas:bagus
# --------------------------------------------------------------------------------
# Baju oke , rekomen banget buat lebaran
# --------------------------------------------------------------------------------
# Kualitas:bagus
# --------------------------------------------------------------------------------
# Saran Tampilan:Bagus
# --------------------------------------------------------------------------------
# Ternyata bahannya tipis
# --------------------------------------------------------------------------------
# Good job 👍
# --------------------------------------------------------------------------------
# Kualitas:bagus
# --------------------------------------------------------------------------------
# Kualitas:baik
# --------------------------------------------------------------------------------
# Mntp
# --------------------------------------------------------------------------------
# Styling:kekecilan
# --------------------------------------------------------------------------------
# Kualitas mantap sesuai harga... Kwrennn
# --------------------------------------------------------------------------------
# Barang nya bagus
# --------------------------------------------------------------------------------
# Sangat bagus
# --------------------------------------------------------------------------------
# Kualitas:95%bagus
# Kenyamanan:pas
# --------------------------------------------------------------------------------
# Saran Tampilan:jelek banget kain nya
# --------------------------------------------------------------------------------
# Styling:biasa
# Kualitas:biasa
# Kenyamanan:biasa
# --------------------------------------------------------------------------------
# Lumayan. .. Tp agak sempit d badan pdhal udh xxxl
# --------------------------------------------------------------------------------
# Pesanan sesuai recomendes
# --------------------------------------------------------------------------------
# Styling:bagus
#
# Bagus,worth it
# --------------------------------------------------------------------------------
# Alhamdulillah bagus 😊
# --------------------------------------------------------------------------------
# Kualitas:Bahan Bagus
# --------------------------------------------------------------------------------
# Sepadan dengan Uang:lumayan
# --------------------------------------------------------------------------------
# Bagus bajunya
# --------------------------------------------------------------------------------
# Terima kasih
# --------------------------------------------------------------------------------
# bagus top
# --------------------------------------------------------------------------------
# Oke bagus
# --------------------------------------------------------------------------------
# Mantap 👍
# --------------------------------------------------------------------------------
# Lumayan
# --------------------------------------------------------------------------------
# Bagus
# --------------------------------------------------------------------------------
# Mantap
# --------------------------------------------------------------------------------
# Bagus
# --------------------------------------------------------------------------------
# Bagus
# --------------------------------------------------------------------------------
# Nice
# --------------------------------------------------------------------------------
# Mudah2an bagus
# --------------------------------------------------------------------------------
# Kualitas:tipis
# --------------------------------------------------------------------------------
# XL nya kecil
# --------------------------------------------------------------------------------
# Kainya tipis
# --------------------------------------------------------------------------------
# Agak sesuai
# --------------------------------------------------------------------------------
# Kualitas:baik
# Saran Tampilan:baik
#
# Sesuai pesanan
# --------------------------------------------------------------------------------
# pesen 2 datengnya 1
# --------------------------------------------------------------------------------
# warna tidk sesuai
# --------------------------------------------------------------------------------
# Saran Tampilan:Baik
# --------------------------------------------------------------------------------
# Bahannya tipis
# --------------------------------------------------------------------------------
# Perfect
# --------------------------------------------------------------------------------
# Sesuai pesanan
# --------------------------------------------------------------------------------
# Kualitas:Baik
# --------------------------------------------------------------------------------
# Paket nya sudah datang sesuai pesanan makasih gan
# --------------------------------------------------------------------------------
# Barang joss
# --------------------------------------------------------------------------------
# Belum di coba
# --------------------------------------------------------------------------------
# Bahan agak tipis
# --------------------------------------------------------------------------------
# Kualitas:bahannya tipis
# --------------------------------------------------------------------------------
# Barang tidak layak di pakek.nyesel
# --------------------------------------------------------------------------------
# Bagus suami sukaa..
# 🙏🙏🤩
# --------------------------------------------------------------------------------
# Oke banget la
# --------------------------------------------------------------------------------
# Kenyamanan:ok
# Kualitas:Ok
# Sepadan dengan Uang:Ok
# --------------------------------------------------------------------------------
# Bajunya baju sesuai dgn saya pesan...
# --------------------------------------------------------------------------------
# Kenyamanan:mantapppp
# --------------------------------------------------------------------------------
# Styling:mantep bahannya cocok ama pesanan
# --------------------------------------------------------------------------------
# kekecilan xl nya ga kaya xl yg besar🥺
# --------------------------------------------------------------------------------
# Kualitas:bagus
# --------------------------------------------------------------------------------
# Sepadan dengan Uang:lumayan
#
# Bagus
# --------------------------------------------------------------------------------
# Bajunya bagus
# --------------------------------------------------------------------------------
# Kualitas:ok
# --------------------------------------------------------------------------------
# Ok
# --------------------------------------------------------------------------------
# Styling:oke
# Kenyamanan:oke
#
# Baik pengiriman cepat
# --------------------------------------------------------------------------------
# Mantap, saya suka sekali....
# --------------------------------------------------------------------------------
# Thankyouu...adekku sukak😘
# --------------------------------------------------------------------------------
# Kualitas:standart
# --------------------------------------------------------------------------------
# Saran Tampilan:tidak sesuai barang dengan di foto
# --------------------------------------------------------------------------------
# Sepadan dengan Uang:iya
# --------------------------------------------------------------------------------
# Baguss
# --------------------------------------------------------------------------------
# barang  ok  bagus
# --------------------------------------------------------------------------------
# Kualitas:bagus. sesuai harga, adem kainnya
# --------------------------------------------------------------------------------
# Bhan tpis
# --------------------------------------------------------------------------------
# Bahannya tipissssss....
# --------------------------------------------------------------------------------
# Sesuwai gambar
# --------------------------------------------------------------------------------
# Ok
# --------------------------------------------------------------------------------
# Mantap sesuai diskripsi
# --------------------------------------------------------------------------------
# Saran Tampilan:sesuai mantap
# --------------------------------------------------------------------------------
# Bahan ternyata panas jika dipakai. Agak kecewa
# --------------------------------------------------------------------------------
# Kurang besar sedikit
# --------------------------------------------------------------------------------
# Thanks Shopee
# --------------------------------------------------------------------------------
# lumayan sii sesuai harga pengiriman b aja
# --------------------------------------------------------------------------------
# Barang bagus tidak mengecewakan 👍
# --------------------------------------------------------------------------------
# Warna:oke
# Tampilan:oke
# --------------------------------------------------------------------------------
# Mayan
# --------------------------------------------------------------------------------
# Tampilan:lumayan
# Warna:hitam
# --------------------------------------------------------------------------------
# Tampilan:Bahan adem, barang sesuai dipesan
# --------------------------------------------------------------------------------
# Bagus
# --------------------------------------------------------------------------------
# Tampilan:bagus pass
# --------------------------------------------------------------------------------
# Bagud
# --------------------------------------------------------------------------------
# Kualitas:jos
# --------------------------------------------------------------------------------
# Kualitas:bagus tapi bahan nya agak tipis
# --------------------------------------------------------------------------------
# Bagusssssssss 😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍
# --------------------------------------------------------------------------------
# Garcep, langsung dikirim
# Thanks 😊😊😊😊😊😊😊😊😊😊😊😊😊😊😊😊😊😇😇😇😇😇😇😇😇😊😊😊😊😊😊😊😊😊😊
# --------------------------------------------------------------------------------
# bahan panas.. tipis.. bnyk benang.. trus kancing nya juga mau lepas2😣😣😣 mau di balikin kasian gak di balikin keselll
# --------------------------------------------------------------------------------
# Bahan nya bagus dgn harga sgtu... kurir ny jg ramaha... mksh lazada
# --------------------------------------------------------------------------------

# %%
import math
cleaned_texts = []

# Iterate through the scraped_texts
for text in new_texts:
    casefolding(text)
    cleansing(text)
    # Skip empty strings and NaN values
    if text != '' and not isinstance(text, float) or not math.isnan(text):
        cleaned_texts.append(text)

new_texts

# %%
new_texts = [casefolding(item) for item in new_texts]
new_texts = [cleansing(item) for item in new_texts]

# %%
new_X = vectorizer.transform(new_texts)
predictions = knn.predict(new_X)

# Print the predictions
for text, label in zip(new_texts, predictions):
    print(f'Text: {text}  Prediction: {label}')
